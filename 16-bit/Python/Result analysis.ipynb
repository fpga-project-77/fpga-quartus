# %%
from ast import literal_eval

# %%
final = open ("final.txt", "a")
result = open ("D:\\Academic\\ACA\\SEM5 TRONIC ACA\\SEMESTER 5\\CSD\\FPGA\\00 - Git\\fpga-quartus\\16-bit\\MULTI_CORE_edit\\result.txt", "r")
d_mem = open ("D:\\Academic\\ACA\\SEM5 TRONIC ACA\\SEMESTER 5\\CSD\\FPGA\\00 - Git\\fpga-quartus\\16-bit\\MULTI_CORE_edit\\data_mem.txt", "r")

# %%
core_1_rows = int(literal_eval('0x' + d_mem.readline().strip()))
core_2_rows = int(literal_eval('0x' + d_mem.readline().strip()))
core_3_rows = int(literal_eval('0x' + d_mem.readline().strip()))
core_4_rows = int(literal_eval('0x' + d_mem.readline().strip()))
core_5_rows = int(literal_eval('0x' + d_mem.readline().strip()))
core_6_rows = int(literal_eval('0x' + d_mem.readline().strip()))
core_7_rows = int(literal_eval('0x' + d_mem.readline().strip()))
core_8_rows = int(literal_eval('0x' + d_mem.readline().strip()))
core_rows = [core_1_rows, core_2_rows, core_3_rows, core_4_rows, core_5_rows, core_6_rows, core_7_rows, core_8_rows]
M = int(literal_eval('0x' + d_mem.readline().strip()))
N = int(literal_eval('0x' + d_mem.readline().strip()))

# %%
mem_start_core_1 = 1023 + 3
mem_start_core_8 = 1151 + 3
mem_start_core_4 = 1279 + 3
mem_start_core_5 = 1407 + 3
mem_start_core_2 = 1535 + 3
mem_start_core_7 = 1663 + 3
mem_start_core_3 = 1791 + 3
mem_start_core_6 = 1919 + 3

# %%
count = 0
matt = []
row = []
for i in result:
    if (core_2_rows == core_3_rows == core_4_rows == core_5_rows == core_6_rows == core_7_rows == core_8_rows ==0):
        if((mem_start_core_1 <= count < 2050) and (i != "xxxx\n")):
            x = '0x' + i.strip()
            row.append(literal_eval(x))
    elif ((core_1_rows >= 1 and core_2_rows >= 1) and (core_3_rows == core_4_rows == 0)):
        if((mem_start_core_1 <= count < mem_start_core_2) and (i != "xxxx\n")):
            x = '0x' + i.strip()
            row.append(literal_eval(x)) 
        if (count == mem_start_core_2):
            matt.append(row)
            row = []
        if((mem_start_core_2 <= count < 2050) and (i != "xxxx\n")):
            x = '0x' + i.strip()
            row.append(literal_eval(x))
    elif ((core_1_rows >= 1 and core_2_rows >= 1 and core_3_rows >= 1) and (core_4_rows == core_5_rows == 0)):
        if((mem_start_core_1 <= count < mem_start_core_2) and (i != "xxxx\n")):
            x = '0x' + i.strip()
            row.append(literal_eval(x)) 
        if (count == mem_start_core_2):
            matt.append(row)
            row = []
        if((mem_start_core_2 <= count < mem_start_core_3) and (i != "xxxx\n")):
            x = '0x' + i.strip()
            row.append(literal_eval(x)) 
        if (count == mem_start_core_3):
            matt.append(row)
            row = []
        if((mem_start_core_3 <= count < 2050) and (i != "xxxx\n")):
            x = '0x' + i.strip()
            row.append(literal_eval(x))
    elif ((core_1_rows >= 1 and core_2_rows >= 1 and core_3_rows >= 1 and core_4_rows >= 1) and (core_5_rows == core_6_rows == 0)):
        if((mem_start_core_1 <= count < mem_start_core_4) and (i != "xxxx\n")):
            x = '0x' + i.strip()
            row.append(literal_eval(x)) 
        if (count == mem_start_core_4):
            matt.append(row)
            row = []
        if((mem_start_core_4 <= count < mem_start_core_2) and (i != "xxxx\n")):
            x = '0x' + i.strip()
            row.append(literal_eval(x)) 
        if (count == mem_start_core_2):
            matt.append(row)
            row = []
        if((mem_start_core_2 <= count < mem_start_core_3) and (i != "xxxx\n")):
            x = '0x' + i.strip()
            row.append(literal_eval(x)) 
        if (count == mem_start_core_3):
            matt.append(row)
            row = []
        if((mem_start_core_3 <= count < 2050) and (i != "xxxx\n")):
            x = '0x' + i.strip()
            row.append(literal_eval(x))   
    elif ((core_1_rows >= 1 and core_2_rows >= 1 and core_3_rows >= 1 and core_4_rows >= 1  and core_5_rows >= 1) and (core_6_rows == core_7_rows == 0)):
        if((mem_start_core_1 <= count < mem_start_core_4) and (i != "xxxx\n")):
            x = '0x' + i.strip()
            row.append(literal_eval(x)) 
        if (count == mem_start_core_4):
            matt.append(row)
            row = []
        if((mem_start_core_4 <= count < mem_start_core_5) and (i != "xxxx\n")):
            x = '0x' + i.strip()
            row.append(literal_eval(x)) 
        if (count == mem_start_core_5):
            matt.append(row)
            row = []
        if((mem_start_core_5 <= count < mem_start_core_2) and (i != "xxxx\n")):
            x = '0x' + i.strip()
            row.append(literal_eval(x)) 
        if (count == mem_start_core_2):
            matt.append(row)
            row = []
        if((mem_start_core_2 <= count < mem_start_core_3) and (i != "xxxx\n")):
            x = '0x' + i.strip()
            row.append(literal_eval(x)) 
        if (count == mem_start_core_3):
            matt.append(row)
            row = []
        if((mem_start_core_3 <= count < 2050) and (i != "xxxx\n")):
            x = '0x' + i.strip()
            row.append(literal_eval(x))   
    elif ((core_1_rows >= 1 and core_2_rows >= 1 and core_3_rows >= 1 and core_4_rows >= 1  and core_5_rows >= 1 and core_6_rows >= 1) and (core_7_rows == core_8_rows == 0)):
        if((mem_start_core_1 <= count < mem_start_core_4) and (i != "xxxx\n")):
            x = '0x' + i.strip()
            row.append(literal_eval(x)) 
        if (count == mem_start_core_4):
            matt.append(row)
            row = []
        if((mem_start_core_4 <= count < mem_start_core_5) and (i != "xxxx\n")):
            x = '0x' + i.strip()
            row.append(literal_eval(x)) 
        if (count == mem_start_core_5):
            matt.append(row)
            row = []
        if((mem_start_core_5 <= count < mem_start_core_2) and (i != "xxxx\n")):
            x = '0x' + i.strip()
            row.append(literal_eval(x)) 
        if (count == mem_start_core_2):
            matt.append(row)
            row = []
        if((mem_start_core_2 <= count < mem_start_core_3) and (i != "xxxx\n")):
            x = '0x' + i.strip()
            row.append(literal_eval(x)) 
        if (count == mem_start_core_3):
            matt.append(row)
            row = []
        if((mem_start_core_3 <= count < mem_start_core_6) and (i != "xxxx\n")):
            x = '0x' + i.strip()
            row.append(literal_eval(x)) 
        if (count == mem_start_core_6):
            matt.append(row)
            row = []
        if((mem_start_core_6 <= count < 2050) and (i != "xxxx\n")):
            x = '0x' + i.strip()
            row.append(literal_eval(x))   
    elif ((core_1_rows >= 1 and core_2_rows >= 1 and core_3_rows >= 1 and core_4_rows >= 1  and core_5_rows >= 1 and core_6_rows >= 1 and core_7_rows >= 1) and (core_8_rows == 0)):
        if((mem_start_core_1 <= count < mem_start_core_4) and (i != "xxxx\n")):
            x = '0x' + i.strip()
            row.append(literal_eval(x)) 
        if (count == mem_start_core_4):
            matt.append(row)
            row = []
        if((mem_start_core_4 <= count < mem_start_core_5) and (i != "xxxx\n")):
            x = '0x' + i.strip()
            row.append(literal_eval(x)) 
        if (count == mem_start_core_5):
            matt.append(row)
            row = []
        if((mem_start_core_5 <= count < mem_start_core_2) and (i != "xxxx\n")):
            x = '0x' + i.strip()
            row.append(literal_eval(x)) 
        if (count == mem_start_core_2):
            matt.append(row)
            row = []
        if((mem_start_core_2 <= count < mem_start_core_7) and (i != "xxxx\n")):
            x = '0x' + i.strip()
            row.append(literal_eval(x)) 
        if (count == mem_start_core_7):
            matt.append(row)
            row = []
        if((mem_start_core_7 <= count < mem_start_core_3) and (i != "xxxx\n")):
            x = '0x' + i.strip()
            row.append(literal_eval(x)) 
        if (count == mem_start_core_3):
            matt.append(row)
            row = []           
        if((mem_start_core_3 <= count < mem_start_core_6) and (i != "xxxx\n")):
            x = '0x' + i.strip()
            row.append(literal_eval(x)) 
        if (count == mem_start_core_6):
            matt.append(row)
            row = []
        if((mem_start_core_6 <= count < 2050) and (i != "xxxx\n")):
            x = '0x' + i.strip()
            row.append(literal_eval(x))
    else:
        if((mem_start_core_1 <= count < mem_start_core_8) and (i != "xxxx\n")):             #core1
            x = '0x' + i.strip()
            row.append(literal_eval(x))
        if (count == mem_start_core_8):
            matt.append(row)
            row = []
        if((mem_start_core_8 <= count < mem_start_core_4) and (i != "xxxx\n")):             #core8
            x = '0x' + i.strip()
            row.append(literal_eval(x))
        if (count == mem_start_core_4):
            matt.append(row)
            row = []
        if((mem_start_core_4 <= count < mem_start_core_5) and (i != "xxxx\n")):             #core4
            x = '0x' + i.strip()
            row.append(literal_eval(x))
        if (count == mem_start_core_5):
            matt.append(row)
            row = []
        if((mem_start_core_5 <= count < mem_start_core_2) and (i != "xxxx\n")):             #core5
            x = '0x' + i.strip()
            row.append(literal_eval(x))
        if (count == mem_start_core_2):
            matt.append(row)
            row = []
        if((mem_start_core_2 <= count < mem_start_core_7) and (i != "xxxx\n")):             #core2
            x = '0x' + i.strip()
            row.append(literal_eval(x))
        if (count == mem_start_core_7):
            matt.append(row)
            row = []
        if((mem_start_core_7 <= count < mem_start_core_3) and (i != "xxxx\n")):              #core7
            x = '0x' + i.strip()
            row.append(literal_eval(x))
        if (count == mem_start_core_3):
            matt.append(row)
            row = []
        if((mem_start_core_3 <= count < mem_start_core_6) and (i != "xxxx\n")):             #core3
            x = '0x' + i.strip()
            row.append(literal_eval(x))
        if (count == mem_start_core_6):
            matt.append(row)
            row = []
        if((mem_start_core_6 <= count) and (i != "xxxx\n")):                                #core6
            x = '0x' + i.strip()
            row.append(literal_eval(x))
    if (count == 2050):
        matt.append(row)
        row = []
    count += 1
    
print (matt)

if((core_1_rows >= 1 and core_2_rows >= 1 ) and (core_3_rows == core_4_rows == 0)):
    matt = [matt[0], matt[1], [], [], [], [], [], []]    
if((core_1_rows >= 1 and core_2_rows >= 1 and core_3_rows >= 1) and (core_4_rows == core_5_rows == 0)):
    matt = [matt[0], matt[1], matt[2], [], [], [], [], []]
if((core_1_rows >= 1 and core_2_rows >= 1 and core_3_rows >= 1 and core_4_rows >= 1) and (core_5_rows == core_6_rows == 0)):
    matt = [matt[0], matt[2], matt[3], matt[1], [], [], [], []]
if((core_1_rows >= 1 and core_2_rows >= 1 and core_3_rows >= 1 and core_4_rows >= 1  and core_5_rows >= 1) and (core_6_rows == core_7_rows == 0)):
    matt = [matt[0], matt[3], matt[4], matt[1], matt[2], [], [], []]
if((core_1_rows >= 1 and core_2_rows >= 1 and core_3_rows >= 1 and core_4_rows >= 1  and core_5_rows >= 1 and core_6_rows >= 1) and (core_7_rows == core_8_rows == 0)):
    matt = [matt[0], matt[3], matt[4], matt[1], matt[2], matt[5], [], []]
if((core_1_rows >= 1 and core_2_rows >= 1 and core_3_rows >= 1 and core_4_rows >= 1  and core_5_rows >= 1 and core_6_rows >= 1 and core_7_rows >= 1) and (core_8_rows == 0)):
    matt = [matt[0], matt[3], matt[5], matt[1], matt[2], matt[6], matt[4], []]
if((core_1_rows >= 1 and core_2_rows >= 1 and core_3_rows >= 1 and core_4_rows >= 1  and core_5_rows >= 1 and core_6_rows >= 1 and core_7_rows >= 1 and core_8_rows >= 1) ):
    matt = [matt[0], matt[4], matt[6], matt[2], matt[3], matt[7], matt[5], matt[1]]
# Out:
# [[10175, 209, 203, 203, 203, 6090, 4060, 3045, 9101, 407, 203, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 2675, 59, 53, 53, 53, 1590, 1060, 795, 2351, 107, 53, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 2472, 57, 49, 49, 49, 1470, 980, 735, 2223, 99, 49, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 2619, 62, 52, 52, 52, 1560, 1040, 780, 2410, 105, 52, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 5072, 109, 101, 101, 101, 3030, 2020, 1515, 4563, 203, 101, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 6475, 135, 129, 129, 129, 3870, 2580, 1935, 5771, 259, 129, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 225, 10, 4, 4, 4, 120, 80, 60, 146, 9, 4, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 463, 23, 9, 9, 9, 270, 180, 135, 579, 19, 9, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 466, 21, 9, 9, 9, 270, 180, 135, 527, 19, 9, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 563, 25, 11, 11, 11, 330, 220, 165, 669, 23, 11, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 472, 17, 9, 9, 9, 270, 180, 135, 423, 19, 9, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 5675, 119, 113, 113, 113, 3390, 2260, 1695, 5051, 227, 113, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 669, 23, 13, 13, 13, 390, 260, 195, 655, 27, 13, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 766, 27, 15, 15, 15, 450, 300, 225, 797, 31, 15, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 1213, 38, 24, 24, 24, 720, 480, 360, 1254, 49, 24, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 1310, 42, 26, 26, 26, 780, 520, 390, 1396, 53, 26, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 1307, 44, 26, 26, 26, 780, 520, 390, 1448, 53, 26, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 1254, 45, 25, 25, 25, 750, 500, 375, 1455, 51, 25, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 1151, 45, 23, 23, 23, 690, 460, 345, 1417, 47, 23, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 825, 22, 16, 16, 16, 480, 320, 240, 686, 33, 16, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 816, 28, 16, 16, 16, 480, 320, 240, 842, 33, 16, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 2363, 61, 47, 47, 47, 1410, 940, 705, 2289, 95, 47, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 10175, 209, 203, 203, 203, 6090, 4060, 3045, 9101, 407, 203, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 2675, 59, 53, 53, 53, 1590, 1060, 795, 2351, 107, 53, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 2472, 57, 49, 49, 49, 1470, 980, 735, 2223, 99, 49, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 2619, 62, 52, 52, 52, 1560, 1040, 780, 2410, 105, 52, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 5072, 109, 101, 101, 101, 3030, 2020, 1515, 4563, 203, 101, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 6475, 135, 129, 129, 129, 3870, 2580, 1935, 5771, 259, 129, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 225, 10, 4, 4, 4, 120, 80, 60, 146, 9, 4, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 463, 23, 9, 9, 9, 270, 180, 135, 579, 19, 9, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 466, 21, 9, 9, 9, 270, 180, 135, 527, 19, 9, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 563, 25, 11, 11, 11, 330, 220, 165, 669, 23, 11, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 472, 17, 9, 9, 9, 270, 180, 135, 423, 19, 9, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 5675, 119, 113, 113, 113, 3390, 2260, 1695, 5051, 227, 113, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 669, 23, 13, 13, 13, 390, 260, 195, 655, 27, 13, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 766, 27, 15, 15, 15, 450, 300, 225, 797, 31, 15, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66]]

# %%
print (matt)
# Out:
# [[10175, 209, 203, 203, 203, 6090, 4060, 3045, 9101, 407, 203, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 2675, 59, 53, 53, 53, 1590, 1060, 795, 2351, 107, 53, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 2472, 57, 49, 49, 49, 1470, 980, 735, 2223, 99, 49, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 2619, 62, 52, 52, 52, 1560, 1040, 780, 2410, 105, 52, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 5072, 109, 101, 101, 101, 3030, 2020, 1515, 4563, 203, 101, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 6475, 135, 129, 129, 129, 3870, 2580, 1935, 5771, 259, 129, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 225, 10, 4, 4, 4, 120, 80, 60, 146, 9, 4, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 463, 23, 9, 9, 9, 270, 180, 135, 579, 19, 9, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 466, 21, 9, 9, 9, 270, 180, 135, 527, 19, 9, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 563, 25, 11, 11, 11, 330, 220, 165, 669, 23, 11, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 472, 17, 9, 9, 9, 270, 180, 135, 423, 19, 9, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 5675, 119, 113, 113, 113, 3390, 2260, 1695, 5051, 227, 113, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 669, 23, 13, 13, 13, 390, 260, 195, 655, 27, 13, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 766, 27, 15, 15, 15, 450, 300, 225, 797, 31, 15, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 1213, 38, 24, 24, 24, 720, 480, 360, 1254, 49, 24, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 1310, 42, 26, 26, 26, 780, 520, 390, 1396, 53, 26, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 1307, 44, 26, 26, 26, 780, 520, 390, 1448, 53, 26, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 1254, 45, 25, 25, 25, 750, 500, 375, 1455, 51, 25, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 1151, 45, 23, 23, 23, 690, 460, 345, 1417, 47, 23, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 825, 22, 16, 16, 16, 480, 320, 240, 686, 33, 16, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 816, 28, 16, 16, 16, 480, 320, 240, 842, 33, 16, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 2363, 61, 47, 47, 47, 1410, 940, 705, 2289, 95, 47, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 10175, 209, 203, 203, 203, 6090, 4060, 3045, 9101, 407, 203, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 2675, 59, 53, 53, 53, 1590, 1060, 795, 2351, 107, 53, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 2472, 57, 49, 49, 49, 1470, 980, 735, 2223, 99, 49, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 2619, 62, 52, 52, 52, 1560, 1040, 780, 2410, 105, 52, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 5072, 109, 101, 101, 101, 3030, 2020, 1515, 4563, 203, 101, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 6475, 135, 129, 129, 129, 3870, 2580, 1935, 5771, 259, 129, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 225, 10, 4, 4, 4, 120, 80, 60, 146, 9, 4, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 463, 23, 9, 9, 9, 270, 180, 135, 579, 19, 9, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 466, 21, 9, 9, 9, 270, 180, 135, 527, 19, 9, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 563, 25, 11, 11, 11, 330, 220, 165, 669, 23, 11, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 472, 17, 9, 9, 9, 270, 180, 135, 423, 19, 9, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 5675, 119, 113, 113, 113, 3390, 2260, 1695, 5051, 227, 113, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 669, 23, 13, 13, 13, 390, 260, 195, 655, 27, 13, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66, 766, 27, 15, 15, 15, 450, 300, 225, 797, 31, 15, 4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66]]

# %%
#matt = [[55, 35, 115,35, 55, 95,55, 35, 115]]
#core_rows = [3,0,0,0]

final_mat = []
print (core_rows)
for j in range(8):
    if(core_rows[j] > 1):
        l = len(matt[j])
        print(l)
        no_per_row = int(l/core_rows[j])
        print (no_per_row)
        counter = 0
        while (counter != l):
            row = []
            for i in range(no_per_row):
                row.append(matt[j][counter])
                counter +=1
            final_mat.append(row)
            #counter += no_per_row
    elif (core_rows[j] == 1):
        final_mat.append(matt[j])
print (final_mat)
# Out:
# [72, 0, 0, 0, 0, 0, 0, 0]
# 792
# 11
# [[10175, 209, 203, 203, 203, 6090, 4060, 3045, 9101, 407, 203], [4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66], [2675, 59, 53, 53, 53, 1590, 1060, 795, 2351, 107, 53], [4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66], [2472, 57, 49, 49, 49, 1470, 980, 735, 2223, 99, 49], [4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66], [2619, 62, 52, 52, 52, 1560, 1040, 780, 2410, 105, 52], [4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66], [5072, 109, 101, 101, 101, 3030, 2020, 1515, 4563, 203, 101], [4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66], [6475, 135, 129, 129, 129, 3870, 2580, 1935, 5771, 259, 129], [4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66], [225, 10, 4, 4, 4, 120, 80, 60, 146, 9, 4], [4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66], [463, 23, 9, 9, 9, 270, 180, 135, 579, 19, 9], [4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66], [466, 21, 9, 9, 9, 270, 180, 135, 527, 19, 9], [4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66], [563, 25, 11, 11, 11, 330, 220, 165, 669, 23, 11], [4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66], [472, 17, 9, 9, 9, 270, 180, 135, 423, 19, 9], [4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66], [5675, 119, 113, 113, 113, 3390, 2260, 1695, 5051, 227, 113], [4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66], [669, 23, 13, 13, 13, 390, 260, 195, 655, 27, 13], [4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66], [766, 27, 15, 15, 15, 450, 300, 225, 797, 31, 15], [4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66], [1213, 38, 24, 24, 24, 720, 480, 360, 1254, 49, 24], [4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66], [1310, 42, 26, 26, 26, 780, 520, 390, 1396, 53, 26], [4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66], [1307, 44, 26, 26, 26, 780, 520, 390, 1448, 53, 26], [4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66], [1254, 45, 25, 25, 25, 750, 500, 375, 1455, 51, 25], [4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66], [1151, 45, 23, 23, 23, 690, 460, 345, 1417, 47, 23], [4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66], [825, 22, 16, 16, 16, 480, 320, 240, 686, 33, 16], [4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66], [816, 28, 16, 16, 16, 480, 320, 240, 842, 33, 16], [4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66], [2363, 61, 47, 47, 47, 1410, 940, 705, 2289, 95, 47], [4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66], [10175, 209, 203, 203, 203, 6090, 4060, 3045, 9101, 407, 203], [4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66], [2675, 59, 53, 53, 53, 1590, 1060, 795, 2351, 107, 53], [4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66], [2472, 57, 49, 49, 49, 1470, 980, 735, 2223, 99, 49], [4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66], [2619, 62, 52, 52, 52, 1560, 1040, 780, 2410, 105, 52], [4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66], [5072, 109, 101, 101, 101, 3030, 2020, 1515, 4563, 203, 101], [4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66], [6475, 135, 129, 129, 129, 3870, 2580, 1935, 5771, 259, 129], [4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66], [225, 10, 4, 4, 4, 120, 80, 60, 146, 9, 4], [4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66], [463, 23, 9, 9, 9, 270, 180, 135, 579, 19, 9], [4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66], [466, 21, 9, 9, 9, 270, 180, 135, 527, 19, 9], [4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66], [563, 25, 11, 11, 11, 330, 220, 165, 669, 23, 11], [4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66], [472, 17, 9, 9, 9, 270, 180, 135, 423, 19, 9], [4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66], [5675, 119, 113, 113, 113, 3390, 2260, 1695, 5051, 227, 113], [4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66], [669, 23, 13, 13, 13, 390, 260, 195, 655, 27, 13], [4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66], [766, 27, 15, 15, 15, 450, 300, 225, 797, 31, 15], [4010, 186, 66, 66, 66, 1980, 1320, 990, 3020, 142, 66]]

# %%
final.write("\n" + "\n" + "Multiplied Matrix(From FPGA)" + "\n")
for i in final_mat:
    final.write(str(i)) 
    final.write("\n")
final.close()
